# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel('Global Superstore Orders 2016.xlsx')
df.rename(columns={'Order Date': 'Order_Date', 'Ship Date': 'Ship_Date'}, inplace=True)
df.head()
# Out:
#    Row ID                  Order ID Order_Date  Ship_Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %%
df['Order_Date'] = df['Order_Date'] + pd.offsets.DateOffset(years=5)
df['Ship_Date'] = df['Ship_Date'] + pd.offsets.DateOffset(years=5)
df
# Out:
#        Row ID                  Order ID Order_Date  Ship_Date       Ship Mode  \
# 0       40098  CA-2014-AB10015140-41954 2019-11-11 2019-11-13     First Class
# 1       26341    IN-2014-JR162107-41675 2019-02-05 2019-02-07    Second Class
# 2       25330    IN-2014-CR127307-41929 2019-10-17 2019-10-18     First Class
# 3       13524   ES-2014-KM1637548-41667 2019-01-28 2019-01-30     First Class
# 4       47221   SG-2014-RH9495111-41948 2019-11-05 2019-11-06        Same Day
# ...       ...                       ...        ...        ...             ...
# 51285   29002   IN-2015-KE1642066-42174 2020-06-19 2020-06-19        Same Day
# 51286   34337  US-2014-ZD21925140-41765 2019-05-06 2019-05-10  Standard Class
# 51287   31315  CA-2012-ZD21925140-41147 2017-08-26 2017-08-31    Second Class
# 51288    9596   MX-2013-RB1979518-41322 2018-02-17 2018-02-21  Standard Class
# 51289    6147   MX-2013-MC1810093-41416 2018-05-22 2018-05-26    Second Class
#
# ...

# %%
pin_date = max(df.Order_Date) + dt.timedelta(1)
df['TotalSum'] = df.Quantity * df.Sales
df.head()
# Out:
#    Row ID                  Order ID Order_Date  Ship_Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2019-11-11 2019-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2019-02-05 2019-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2019-10-17 2019-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2019-01-28 2019-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2019-11-05 2019-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...    Category Sub-Category                               Product Name  \
# ...

# %%
rfm = df.groupby('Customer ID').agg({
    'Order_Date' : lambda x: (pin_date - x.max()).days,
    'Order ID' : 'count', 
    'TotalSum' : 'sum'})
rfm.rename(columns = {'Order_Date' : 'Recency',
                      'Order ID' : 'Frequency', 
                      'TotalSum' : 'Monetary'}, inplace = True)
rfm.head()
# Out:
#               Recency  Frequency   Monetary
# Customer ID
# AA-10315102       360          6   4539.519
# AA-10315120       961          1  18993.870
# AA-10315139       150         13   9767.886
# AA-103151402      185          6  14492.388
# AA-103151404      820          3   1507.016

# %%
rfm['Frequency'] = rfm['Frequency'].astype(float)

r_labels = range(4, 0, -1)
r_groups = pd.qcut(rfm.Recency, q = 4, labels = r_labels)

m_labels = range(1, 5)
m_groups = pd.qcut(rfm.Monetary, q = 4, labels = m_labels)

# %%
def pct_rank_qcut(series, n):
    edges = pd.Series([float(i) / n for i in range(n + 1)])
    f = lambda x: (edges >= x).argmax()
    return series.rank(pct=1).apply(f)

rfm['F'] = pct_rank_qcut(rfm.Frequency, 4)
rfm['R'] = r_groups.values
rfm['M'] = m_groups.values# sum up the three columns
rfm['RFM_Segment'] = rfm.apply(lambda x: str(x['R']) + str(x['F']) + str(x['M']), axis = 1)
rfm['RFM_Score'] = rfm[['R', 'F', 'M']].sum(axis = 1)
rfm.head()
# Out:
#               Recency  Frequency   Monetary  F  R  M RFM_Segment  RFM_Score
# Customer ID
# AA-10315102       360        6.0   4539.519  4  3  4   3.04.04.0         11
# AA-10315120       961        1.0  18993.870  1  1  4   1.01.04.0          6
# AA-10315139       150       13.0   9767.886  4  3  4   3.04.04.0         11
# AA-103151402      185        6.0  14492.388  4  3  4   3.04.04.0         11
# AA-103151404      820        3.0   1507.016  3  1  3   1.03.03.0          7

# %%
score_labels = ['Green', 'Bronze', 'Silver', 'Gold']
score_groups = pd.qcut(rfm.RFM_Score, q = 4, labels = score_labels)
rfm['RFM_Level'] = score_groups.values
rfm.head()
# Out:
#               Recency  Frequency   Monetary  F  R  M RFM_Segment  RFM_Score  \
# Customer ID
# AA-10315102       360        6.0   4539.519  4  3  4   3.04.04.0         11
# AA-10315120       961        1.0  18993.870  1  1  4   1.01.04.0          6
# AA-10315139       150       13.0   9767.886  4  3  4   3.04.04.0         11
# AA-103151402      185        6.0  14492.388  4  3  4   3.04.04.0         11
# AA-103151404      820        3.0   1507.016  3  1  3   1.03.03.0          7
#
#              RFM_Level
# Customer ID
# AA-10315102       Gold
# AA-10315120     Bronze
# AA-10315139       Gold
# AA-103151402      Gold
# AA-103151404    Bronze

# %%
rfm.to_excel('RFM_Segment.xlsx')

# %%
total_avg = rfm.iloc[:, 0:3].mean()
cluster_avg = rfm.groupby('RFM_Level').mean().iloc[:, 0:3]
prop_rfm = cluster_avg/total_avg - 1
sns.heatmap(prop_rfm, cmap= 'Oranges', fmt= '.2f', annot = True)
plt.title('Heatmap')
plt.plot()
# Out:
# []

# %%
rfm_g = rfm.groupby('RFM_Level').count()
color_list = ['green', 'peru','gainsboro','gold']

plt.bar(rfm_g.index, rfm_g.F,color = color_list)
plt.xticks(ticks=rfm_g.index, labels=rfm_g.index)
plt.xlabel('Class')
plt.ylabel('Customer Count')
plt.title('RFM Customer Count')
plt.show()
